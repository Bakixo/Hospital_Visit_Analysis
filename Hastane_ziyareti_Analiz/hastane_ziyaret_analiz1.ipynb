# %% [markdown]
# ## *import*

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
df = pd.read_csv("community_health.csv")

# %%
df.head()
# Out:
#    age  gender race/ethnicity  weight  height  visits
# 0   47  female        group D     247      65      28
# 1   26    male        group C     283      66      23
# 2   26    male        group B     201      68      14
# 3   39    male        group C     237      73      21
# 4   55    male        group A     199      61      27

# %% [markdown]
# ## ABOUT DATA

# %%
df.rename(columns={
    "age" : "yas",
    "gender" : "cinsiyet",
    "race/ethnicity" : "irk",
    "weight" : "kilo",
    "height" : "boy",
    "visits" : "ziyaret"
},inplace=True)

# %%
df
# Out:
#      yas cinsiyet      irk  kilo  boy  ziyaret
# 0     47   female  group D   247   65       28
# 1     26     male  group C   283   66       23
# 2     26     male  group B   201   68       14
# 3     39     male  group C   237   73       21
# 4     55     male  group A   199   61       27
# ..   ...      ...      ...   ...  ...      ...
# 995   43   female  group E   273   68       22
# 996   34   female  group D   247   76       16
# 997   54   female  group B   310   75       27
# 998   38     male  group E    64   75        7
# 999   62   female  group D   213   67       22
#
# [1000 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# yas         0
# cinsiyet    0
# irk         0
# kilo        0
# boy         0
# ziyaret     0
# dtype: int64

# %%
df.describe()
# Out:
#                yas         kilo          boy      ziyaret
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     45.019000   199.045000    67.300000    19.956000
# std      14.839166    52.815077     6.285341     6.455055
# min       0.000000    45.000000    46.000000     2.000000
# 25%      36.000000   165.000000    63.000000    15.000000
# 50%      45.000000   197.000000    67.000000    20.000000
# 75%      55.000000   236.000000    72.000000    24.000000
# max      89.000000   356.000000    86.000000    40.000000

# %% [markdown]
# ## Veriyi Hazırlama

# %% [markdown]
#     Yaş & Visit sayısı arasındaki ilişkiye bakacağız

# %%
df["kilo"] = round(df["kilo"] * 0.45)

# %%
sns.pairplot(df,diag_kind="kde")

# %%
df
# Out:
#      yas cinsiyet      irk   kilo  boy  ziyaret
# 0     47   female  group D  111.0   65       28
# 1     26     male  group C  127.0   66       23
# 2     26     male  group B   90.0   68       14
# 3     39     male  group C  107.0   73       21
# 4     55     male  group A   90.0   61       27
# ..   ...      ...      ...    ...  ...      ...
# 995   43   female  group E  123.0   68       22
# 996   34   female  group D  111.0   76       16
# 997   54   female  group B  140.0   75       27
# 998   38     male  group E   29.0   75        7
# 999   62   female  group D   96.0   67       22
#
# [1000 rows x 6 columns]

# %%
df["boy"] = round(df["boy"] * 2.54)

# %%
df
# Out:
#      yas cinsiyet      irk   kilo    boy  ziyaret
# 0     47   female  group D  111.0  165.0       28
# 1     26     male  group C  127.0  168.0       23
# 2     26     male  group B   90.0  173.0       14
# 3     39     male  group C  107.0  185.0       21
# 4     55     male  group A   90.0  155.0       27
# ..   ...      ...      ...    ...    ...      ...
# 995   43   female  group E  123.0  173.0       22
# 996   34   female  group D  111.0  193.0       16
# 997   54   female  group B  140.0  190.0       27
# 998   38     male  group E   29.0  190.0        7
# 999   62   female  group D   96.0  170.0       22
#
# [1000 rows x 6 columns]

# %%
df["cinsiyet"].replace({
    "male" : 1,
    "female" : 0
},inplace=True)
df.head(5)
# Out:
# C:\Users\baki5\AppData\Local\Temp\ipykernel_1124\473798519.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cinsiyet"].replace({
# C:\Users\baki5\AppData\Local\Temp\ipykernel_1124\473798519.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["cinsiyet"].replace({
# ...

# %%
df["irk"].replace({
    "group A" : 1,
    "group B" : 2,
    "group C" : 3,
    "group D" : 4,
    "group E" : 5
}, inplace=True)
# Out:
# C:\Users\baki5\AppData\Local\Temp\ipykernel_1124\259277286.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["irk"].replace({
# C:\Users\baki5\AppData\Local\Temp\ipykernel_1124\259277286.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["irk"].replace({

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#    yas  cinsiyet  irk   kilo    boy  ziyaret
# 0   47         0    4  111.0  165.0       28
# 1   26         1    3  127.0  168.0       23
# 2   26         1    2   90.0  173.0       14
# 3   39         1    3  107.0  185.0       21
# 4   55         1    1   90.0  155.0       27

# %% [markdown]
# ## TRAİN TEST SPLİT

# %%
# df.to_csv("community_health_MLR", index=False)

# %%
df2 = pd.read_csv("community_health_MLR.csv")

# %%
df2
# Out:
#      yas  cins  irk   kilo    boy  visits
# 0     47     0    4  112.0  165.0      28
# 1     26     1    3  128.0  168.0      23
# 2     26     1    2   91.0  173.0      14
# 3     39     1    3  108.0  185.0      21
# 4     55     1    1   90.0  155.0      27
# ..   ...   ...  ...    ...    ...     ...
# 995   43     0    5  124.0  173.0      22
# 996   34     0    4  112.0  193.0      16
# 997   54     0    2  141.0  190.0      27
# 998   38     1    5   29.0  190.0       7
# 999   62     0    4   97.0  170.0      22
#
# [1000 rows x 6 columns]

# %%
X = df2.drop("visits",axis = 1)

# %%
y = df2["visits"]

# %%
X.head()
# Out:
#    yas  cins  irk   kilo    boy
# 0   47     0    4  112.0  165.0
# 1   26     1    3  128.0  168.0
# 2   26     1    2   91.0  173.0
# 3   39     1    3  108.0  185.0
# 4   55     1    1   90.0  155.0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=99)

# %%
X_train.head()
# Out:
#      yas  cins  irk   kilo    boy
# 26    45     0    4  101.0  196.0
# 155   21     1    5   85.0  178.0
# 872   47     1    2   62.0  178.0
# 383   64     0    4   72.0  173.0
# 648   50     1    3   93.0  163.0

# %%
X_test
# Out:
#      yas  cins  irk   kilo    boy
# 890   72     1    2   88.0  175.0
# 983   47     0    2   79.0  183.0
# 107   16     0    2  108.0  170.0
# 609   34     0    2   61.0  168.0
# 113   50     1    2  133.0  170.0
# ..   ...   ...  ...    ...    ...
# 884   85     0    5   63.0  155.0
# 615   67     0    3   83.0  165.0
# 910   23     1    5   99.0  196.0
# 735   73     1    5   48.0  173.0
# 494   42     0    1   39.0  168.0
#
# [300 rows x 5 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
regr = LinearRegression()

# %%
regr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_preds = regr.predict(X_test)

# %%
test_preds
# Out:
# array([25.53512869, 16.22982385, 15.97912443, 12.46832106, 28.93358077,
#        12.389785  , 18.38814689, 12.96058291, 25.8973212 , 16.62758758,
#        14.57865887, 17.42854142, 16.76456796, 17.06723232, 28.69096064,
#        12.60401467, 17.39141919, 22.89426937, 24.71720408, 11.35643946,
#        10.84374258, 30.69086579, 20.46700995, 17.09777173, 23.05278211,
#        23.09057772, 22.23810566, 15.12479879, 30.51677773, 14.84632904,
#        18.25287147, 27.95266181, 22.8178326 , 28.63934915, 27.25987384,
#        12.95169388, 18.30004476, 21.00345594, 10.56079031, 24.31519054,
#        19.42928903, 18.61042318, 25.04635549, 21.16227353, 13.32367912,
#        16.20588478, 25.28275735,  8.83098891, 19.92054526, 25.91195305,
#        20.81099459, 24.30145098, 23.15477623, 16.78292119,  7.84596864,
#        17.87425201, 13.83471239, 17.27889091, 29.14270437, 20.62357981,
#        21.5864883 , 19.15572275, 13.35185501, 25.3130877 , 18.26486612,
# ...

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print("Theta :     ", round(regr.coef_[0],2))
print("Intercept : ", round(regr.intercept_,2))
print("R^2 :       ", round(r2_score(y_test,test_preds),2))
print("MAE :       ", round(mean_absolute_error(y_test,test_preds),2))
print("RMSE :      ", round(np.sqrt(mean_squared_error(y_test,test_preds)),2)) 

# WOW BAYA İYİ
# Out:
# Theta :      0.25
# Intercept :  22.8
# R^2 :        0.84
# MAE :        2.24
# RMSE :       2.64

# %%
df2["visits"].mean() , df2["visits"].std()
# Out:
# (19.956, 6.455054742737023)

# %%
final = LinearRegression()

# %%
final.fit(X,y)
# Out:
# LinearRegression()

# %%
y_hat = final.predict(X)

# %%
final.coef_ # wow
# Out:
# array([ 0.24622291,  0.10675596,  0.017792  ,  0.17551431, -0.17984967])

# %%
df.head()
# Out:
#    yas  cinsiyet  irk   kilo    boy  ziyaret
# 0   47         0    4  111.0  165.0       28
# 1   26         1    3  127.0  168.0       23
# 2   26         1    2   90.0  173.0       14
# 3   39         1    3  107.0  185.0       21
# 4   55         1    1   90.0  155.0       27

# %%
print(df["yas"].mean())
print(df["cinsiyet"].mean())
print(df["irk"].mean())
print(df["kilo"].mean())
print(df["boy"].mean())
# Out:
# 45.019
# 0.481
# 3.155
# 89.574
# 170.914

# %%
insan_evladi = [[33,0,1,68,162]]

# %%
final.predict(insan_evladi)
# Out:
# c:\Users\baki5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([14.59915006])

# %%
X.iloc[135]
# Out:
# yas      48.0
# cins      1.0
# irk       4.0
# kilo    108.0
# boy     180.0
# Name: 135, dtype: float64

# %%
denek = [[48,1,4,108,180]]

# %%
final.predict(denek)
# Out:
# c:\Users\baki5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([22.23590402])

# %%
y.iloc[135]
# Out:
# 24

# %% [markdown]
# ## Modeli kaydet

# %%
from joblib import dump, load

# %%
dump(final,"dr_hasta_visit_1.joblib " )
# Out:
# ['dr_hasta_visit_1.joblib ']

# %%
model_download = load("dr_hasta_visit_1.joblib")

# %%
model_download.predict(denek)
# Out:
# c:\Users\baki5\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([22.23590402])

# %% [markdown]
# ## RESİDUAL

# %%
residual = y_hat - y

# %%
residual
# Out:
# 0     -2.717272
# 1     -0.530310
# 2      1.058620
# 3     -1.897143
# 4     -1.756927
#          ...
# 995    2.983002
# 996    1.046039
# 997    0.564377
# 998   -2.872661
# 999    3.444108
# Name: visits, Length: 1000, dtype: float64

# %%
sns.scatterplot(x=y,y=residual)
# Out:
# <Axes: xlabel='visits', ylabel='visits'>
